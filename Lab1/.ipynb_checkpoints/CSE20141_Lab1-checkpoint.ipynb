# %%
import numpy as np
import pandas as pd

# %%
#reading the excel sheet1
purchase_data = pd.read_excel(r"C:\Users\Admin\Downloads\Lab Session1 Data.xlsx")
purchase_data
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
#getting the dimension of the dataset
purchase_data.shape
# Out:
# (10, 22)

# %%
#making the dataset into a datframe and thus removing the NaN values using dropna
purchase_dataframe = pd.DataFrame(purchase_data)
purchase_dataframe1 =purchase_dataframe.dropna(axis = 1)
print(purchase_dataframe1)
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198

# %%
#getting the attributes of AX=C
matrix_A = purchase_dataframe1.iloc[:: , 1:4]
print(matrix_A)
matrix_A.shape
# Out:
#    Candies (#)  Mangoes (Kg)  Milk Packets (#)
# 0           20             6                 2
# 1           16             3                 6
# 2           27             6                 2
# 3           19             1                 2
# 4           24             4                 2
# 5           22             1                 5
# 6           15             4                 2
# 7           18             4                 2
# 8           21             1                 4
# 9           16             2                 4
# (10, 3)

# %%
#getting the output of the matrix AX=C
matrix_C = purchase_dataframe1.iloc[:: , 4:5]
print(matrix_C)
matrix_C.shape
# Out:
#    Payment (Rs)
# 0           386
# 1           289
# 2           393
# 3           110
# 4           280
# 5           167
# 6           271
# 7           274
# 8           148
# 9           198
# (10, 1)

# %%
#finding rank of the attribute matrix
rank_A = np.linalg.matrix_rank(matrix_A)
print(rank_A)
# Out:
# 3

# %%
#finding rank of the output matrix
rank_C = np.linalg.matrix_rank(matrix_C)
print(rank_C)
# Out:
# 1

# %%
#pseudo inverse of attribute matrix as it isn't a square matrix
pseudo_inv_A = np.linalg.pinv(matrix_A)
print(pseudo_inv_A)
# Out:
# [[-0.01008596 -0.03124505  0.01013951  0.0290728   0.0182907   0.01161794
#   -0.00771348  0.00095458  0.01743623 -0.00542016]
#  [ 0.09059668  0.07263726  0.03172933 -0.09071908 -0.01893196 -0.06926996
#    0.05675464  0.03152577 -0.07641966  0.00357352]
#  [ 0.00299878  0.15874243 -0.05795468 -0.06609024 -0.06295043  0.03348017
#    0.01541831 -0.01070461  0.00029003  0.05938755]]

# %%
#pseudo inverse of output matrix as it isn't a square matrix
pseudo_inv_C = np.linalg.pinv(matrix_C)
print(pseudo_inv_C)
# Out:
# [[0.00053988 0.00040421 0.00054967 0.00015385 0.00039162 0.00023357
#   0.00037903 0.00038323 0.000207   0.00027693]]

# %%
#multiplying the pseudo inverse of attribute matrix with output matrix in order to get X of AX=C
matrix_X = np.dot(pseudo_inv_A, matrix_C)
print(matrix_X)
# Out:
# [[ 1.]
#  [55.]
#  [18.]]

# %%
#adding an extra column for classifying the customers as Poor or Rich acc to their payment
matrix_C.loc[matrix_C['Payment (Rs)'] <= 200, 'Classification'] = 'Poor' 
matrix_C.loc[matrix_C['Payment (Rs)'] > 200, 'Classification'] = 'Rich' 
print(matrix_C)
# Out:
#    Payment (Rs) Classification
# 0           386           Rich
# 1           289           Rich
# 2           393           Rich
# 3           110           Poor
# 4           280           Rich
# 5           167           Poor
# 6           271           Rich
# 7           274           Rich
# 8           148           Poor
# 9           198           Poor

# %%
#reading the 2nd sheet of the excel doc
stock_price = pd.read_excel(r"C:\Users\Admin\Downloads\Lab Session1 Data.xlsx" , sheet_name = 'IRCTC Stock Price')
stock_price
# Out:
#              Date Month  Day    Price     Open     High      Low   Volume  \
# 0    Jun 29, 2021   Jun  Tue  2081.85  2092.00  2126.90  2065.05    1.67M
# 1    Jun 28, 2021   Jun  Mon  2077.75  2084.00  2112.45  2068.40  707.73K
# 2    Jun 25, 2021   Jun  Fri  2068.85  2084.35  2088.50  2053.10  475.82K
# 3    Jun 24, 2021   Jun  Thu  2072.95  2098.00  2098.00  2066.00  541.51K
# 4    Jun 23, 2021   Jun  Wed  2078.25  2102.00  2111.40  2072.00  809.62K
# ..            ...   ...  ...      ...      ...      ...      ...      ...
# 244  Jul 07, 2020   Jul  Tue  1397.40  1410.00  1411.00  1390.05  480.21K
# 245  Jul 06, 2020   Jul  Mon  1400.75  1405.50  1415.50  1394.00  614.93K
# 246  Jul 03, 2020   Jul  Fri  1405.10  1415.00  1425.00  1398.00  599.49K
# 247  Jul 02, 2020   Jul  Thu  1412.35  1440.00  1467.80  1395.30    2.16M
# 248  Jul 01, 2020   Jul  Wed  1363.05  1363.65  1377.00  1356.00  383.00K
#
#        Chg%
# 0    0.0020
# 1    0.0043
# 2   -0.0020
# 3   -0.0026
# ...

# %%
#finding mean/avg acc to the price column 
price_mean = stock_price[["Price"]].mean()
print("The population mean is: ",price_mean)
# Out:
# The population mean is:  Price    1560.663454
# dtype: float64

# %%
#finding variance acc to the price column
price_variance = stock_price[["Price"]].var()
print("The population variance is: ",price_variance)
# Out:
# The population variance is:  Price    58732.365353
# dtype: float64

# %%
#filtering out all Wednesdays
stock_wed = stock_price.loc[stock_price['Day'] == 'Wed']
stock_wed
# Out:
#              Date Month  Day    Price     Open     High      Low   Volume  \
# 4    Jun 23, 2021   Jun  Wed  2078.25  2102.00  2111.40  2072.00  809.62K
# 9    Jun 16, 2021   Jun  Wed  2089.95  2109.45  2121.95  2075.30  856.94K
# 14   Jun 09, 2021   Jun  Wed  2071.20  2160.00  2163.00  2060.00    2.34M
# 19   Jun 02, 2021   Jun  Wed  1917.95  1899.95  1927.50  1895.25  576.76K
# 24   May 26, 2021   May  Wed  1894.05  1920.00  1930.05  1888.00  922.76K
# 29   May 19, 2021   May  Wed  1858.10  1844.00  1884.95  1840.00    2.10M
# 33   May 12, 2021   May  Wed  1746.60  1799.00  1829.00  1732.80    1.63M
# 38   May 05, 2021   May  Wed  1723.65  1775.00  1782.95  1715.00    1.22M
# 43   Apr 28, 2021   Apr  Wed  1795.85  1800.00  1818.00  1775.00    1.54M
# 56   Apr 07, 2021   Apr  Wed  1709.00  1684.20  1721.40  1673.00    1.47M
# 60   Mar 31, 2021   Mar  Wed  1757.00  1758.70  1774.95  1735.00    1.09M
# 64   Mar 24, 2021   Mar  Wed  1760.55  1829.70  1836.80  1750.40    2.09M
# ...

# %%
#finding mean of all the Wednesdays from the filtered df
stock_wed_mean  = stock_wed[["Price"]].mean()
print("The sample mean for all Wednesdays: ", stock_wed_mean)
# Out:
# The sample mean for all Wednesdays:  Price    1550.706
# dtype: float64

# %%
#finding variance of all the Wednesdays from the filtered df
stock_wed[["Price"]].var()
# Out:
# Price    57939.550167
# dtype: float64

# %%
#comparing the sample mean of all the wednesdays with the population mean
print("The difference between the sample mean and the population mean is: ")
print(abs(stock_wed_mean - price_mean))
# Out:
# The difference between the sample mean and the population mean is:
# Price    9.957454
# dtype: float64

# %%
#filtering out all days in April
stock_apr = stock_price.loc[stock_price['Month'] == 'Apr']
stock_apr
# Out:
#             Date Month  Day    Price     Open     High      Low   Volume  \
# 41  Apr 30, 2021   Apr  Fri  1791.40  1784.90  1809.15  1757.75  756.66K
# 42  Apr 29, 2021   Apr  Thu  1792.55  1801.00  1818.00  1765.30    1.21M
# 43  Apr 28, 2021   Apr  Wed  1795.85  1800.00  1818.00  1775.00    1.54M
# 44  Apr 27, 2021   Apr  Tue  1793.20  1730.00  1802.60  1714.65    2.26M
# 45  Apr 26, 2021   Apr  Mon  1730.85  1721.90  1739.25  1718.00  791.76K
# 46  Apr 23, 2021   Apr  Fri  1712.00  1670.00  1717.90  1661.00    1.63M
# 47  Apr 22, 2021   Apr  Thu  1673.05  1614.00  1681.00  1614.00  988.50K
# 48  Apr 20, 2021   Apr  Tue  1640.05  1616.00  1648.95  1616.00    1.14M
# 49  Apr 19, 2021   Apr  Mon  1612.70  1550.00  1620.00  1550.00    1.19M
# 50  Apr 16, 2021   Apr  Fri  1627.45  1611.00  1638.10  1606.00  968.08K
# 51  Apr 15, 2021   Apr  Thu  1608.10  1592.10  1632.90  1589.00    1.16M
# 52  Apr 13, 2021   Apr  Tue  1611.65  1582.05  1623.00  1582.05    1.23M
# ...

# %%
#finding mean of all the days in April from the filtered df
stock_apr_mean  = stock_apr[["Price"]].mean()
print("The sample mean for all days in April: ",stock_apr_mean)
# Out:
# The sample mean for all days in April:  Price    1698.952632
# dtype: float64

# %%
#finding variance of all the days in April from the filtered df
stock_apr[["Price"]].var()
# Out:
# Price    4877.621798
# dtype: float64

# %%
#comparing the sample mean of all the days in April with the population mean
print("The difference between the sample mean and the population mean is: ")
print(abs(stock_apr_mean - price_mean))
# Out:
# The difference between the sample mean and the population mean is:
# Price    138.289178
# dtype: float64

# %%
#probability of loss over the stock
chg_count = len(stock_price)
print(chg_count)
#stock_price['loss'] = stock_price['Chg%'].apply(lambda x: x < 0)
#print(stock_price['loss'].value_counts())
chg_loss = list(filter(lambda chg: chg < 0, total_chg))
chg_loss_no = len(chg_loss)
loss_prob = chg_loss_no/chg_count
print("The probability of making a loss over a stock is: ", loss_prob)
# Out:
# 249
# The probability of making a loss over a stock is:  0.4979919678714859

# %%
#probability of profit on a Wednesday
chg_count1 = len(stock_wed)
print(chg_count1)
#stock_wed['profit'] = stock_wed['Chg%'].apply(lambda x: x > 0)
#print(stock_wed['profit'].value_counts())
chg_profit = list(filter(lambda chg: chg > 0, stock_wed))
chg_profit_no = len(chg_profit)
profit_prob = chg_profit_no/chg_count
print("The probability of making a profit over a stock on a Wednesday is: ", profit_prob)
# Out:
# 50
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 6>()
#       3 print(chg_count1)
#       4 #stock_wed['profit'] = stock_wed['Chg%'].apply(lambda x: x > 0)
#       5 #print(stock_wed['profit'].value_counts())
# ----> 6 chg_profit = list(filter(lambda chg: chg > 0, stock_wed))
#       7 chg_profit_no = len(chg_profit)
#       8 profit_prob = chg_profit_no/chg_count
#
# Input In [52], in <lambda>(chg)
#       3 print(chg_count1)
#       4 #stock_wed['profit'] = stock_wed['Chg%'].apply(lambda x: x > 0)
#       5 #print(stock_wed['profit'].value_counts())
# ----> 6 chg_profit = list(filter(lambda chg: chg > 0, stock_wed))
#       7 chg_profit_no = len(chg_profit)
#       8 profit_prob = chg_profit_no/chg_count
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
#Calculating the probability of making profit provided that today is a wednesday 
prob_wed = chg_count1/chg_count
prob_profit_given_wed = profit_prob/prob_wed
print("Probability of making profit given it is Wednesday is :",prob_profit_given_wed)
# Out:
# Probability of making profit given it is Wednesday is : 12.3504

# %%
import matplotlib.pyplot as plt
y = stock_price['Chg%']
x = stock_price['Day']
plt.scatter(x,y)
plt.show()
